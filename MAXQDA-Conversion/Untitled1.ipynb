# %%
import requests
r = requests.get("https://amphora.asu.edu/amphora/resource/get?uri=http://diging.asu.edu/uri/leuphana244&format=json", headers={"Token":"974c011d01bd853da0007493c1ac509032eef907"})
r
# Out:
# <Response [200]>

# %%
o = r.json()

# %%
o['url']
# Out:
# 'https://amphora.asu.edu/amphora/rest/content/6800340/?format=json'

# %%
f = {u'aggregate_content': [{u'content_type': u'application/pdf',
                         u'resources': [{u'content_for': 6800153,
                                         u'content_type': u'text/plain',
                                         u'external_source': u'GL',
                                         u'id': 6800155,
                                         u'is_external': True,
                                         u'name': u'245.pdf, page 0 (text)',
                                         u'public': False,
                                         u'uri': u'https://diging.asu.edu/geco-giles/files/FILEvwwjHx3HF3N0',
                                         u'url': u'https://amphora.asu.edu/amphora/rest/content/6800155/?format=json'},
                                        {u'content_for': 6800149,
                                         u'content_type': u'application/pdf',
                                         u'external_source': None,
                                         u'id': 6800148,
                                         u'is_external': False,
                                         u'name': u'245.pdf',
                                         u'public': False,
                                         u'uri': u'https://amphora.asu.edu/amphora/resource/6800148',
                                         u'url': u'https://amphora.asu.edu/amphora/rest/content/6800148/?format=json'},
                                        {u'content_for': 6800153,
                                         u'content_type': u'image/tiff',
                                         u'external_source': u'GL',
                                         u'id': 6800154,
                                         u'is_external': True,
                                         u'name': u'245.pdf, page 0 (image)',
                                         u'public': False,
                                         u'uri': u'https://diging.asu.edu/geco-giles/files/FILEUe1bQFoKS7gE',
                                         u'url': u'https://amphora.asu.edu/amphora/rest/content/6800154/?format=json'},
                                        {u'content_for': 6800149,
                                         u'content_type': u'text/plain',
                                         u'external_source': u'GL',
                                         u'id': 6800151,
                                         u'is_external': True,
                                         u'name': u'https://diging.asu.edu/geco-giles/rest/files/FILEfzePLE7XmYoZ/content',
                                         u'public': False,
                                         u'uri': u'https://diging.asu.edu/geco-giles/rest/files/FILEfzePLE7XmYoZ/content',
                                         u'url': u'https://amphora.asu.edu/amphora/rest/content/6800151/?format=json'},
                                        {u'content_for': 6800149,
                                         u'content_type': u'text/csv',
                                         u'external_source': u'GL',
                                         u'id': 6800152,
                                         u'is_external': True,
                                         u'name': u'https://diging.asu.edu/geco-giles/rest/files/FILERM00cPvaRQe3/content',
                                         u'public': False,
                                         u'uri': u'https://diging.asu.edu/geco-giles/rest/files/FILERM00cPvaRQe3/content',
                                         u'url': u'https://amphora.asu.edu/amphora/rest/content/6800152/?format=json'}]}]}

# %%
f['aggregate_content'][0]['resources'][0]['id']
# Out:
# 6800155

# %%
o
# Out:
# {'url': 'https://amphora.asu.edu/amphora/rest/content/6800340/?format=json',
#  'id': 6800340,
#  'uri': 'http://diging.asu.edu/uri/leuphana244',
#  'name': '245',
#  'public': True,
#  'content': [{'id': 4357820,
#    'content_resource': {'url': 'https://amphora.asu.edu/amphora/rest/content/6800343/?format=json',
#     'id': 6800343,
#     'uri': 'https://diging.asu.edu/geco-giles/rest/files/FILEoawz3AFs5fbl/content',
#     'name': 'https://diging.asu.edu/geco-giles/rest/files/FILEoawz3AFs5fbl/content',
#     'public': False,
#     'is_external': True,
#     'external_source': 'GL',
#     'content_type': 'text/csv',
#     'content_for': 6800340},
#    'content_type': 'text/csv',
#    'content_encoding': None},
#   {'id': 4357819,
#    'content_resource': {'url': 'https://amphora.asu.edu/amphora/rest/content/6800342/?format=json',
#     'id': 6800342,
#     'uri': 'https://diging.asu.edu/geco-giles/rest/files/FILEW6xJpi2pkpC4/content',
# ...

# %%
import difflib

# %%
d = difflib.Differ()

# %%
i = list(d.compare('Hello okasd asokasdknasd', 'Hello asdasdasd'))

# %%
i
# Out:
# ['  H',
#  '  e',
#  '  l',
#  '  l',
#  '  o',
#  '   ',
#  '- o',
#  '- k',
#  '  a',
#  '  s',
#  '  d',
#  '-  ',
#  '- a',
#  '- s',
#  '- o',
#  '- k',
#  '  a',
#  '  s',
#  '  d',
#  '- k',
#  '- n',
#  '  a',
#  '  s',
#  '  d']

# %%
from pprint import pprint

# %%
pprint(i)
# Out:
# ['  H',
#  '  e',
#  '  l',
#  '  l',
#  '  o',
#  '   ',
#  '- o',
#  '- k',
#  '  a',
#  '  s',
#  '  d',
#  '-  ',
#  '- a',
#  '- s',
#  '- o',
#  '- k',
#  '  a',
#  '  s',
#  '  d',
#  '- k',
#  '- n',
#  '  a',
#  '  s',
#  '  d']

# %%
import sys
sys.stdout.writelines(i)
# Out:
#   H  e  l  l  o   - o- k  a  s  d-  - a- s- o- k  a  s  d- k- n  a  s  d
